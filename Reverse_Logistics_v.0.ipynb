# %% [markdown]
# Here, I have included main features like Return Rate, Fraud Rate, Post Verification, Customer Classification.
# Return Rate and Fraud Rate has been calculated using the respective formula by taking the values from the corresponding
# features.
#
# Post Verification is classified as 'Fraudulent', 'Genuine', 'Fail to Return'
# Fraudulent - even after the pre verification after picking up the return item, the item found to be fake
# Genuine - item returned is the original one
# Fail to return - one who hasn't completed the pre verification
#
# Pre verification - Verification made like, uploading images of the item, sharing searial no. etc.
#
# After all these steps Fraud Rate is calculated and set a threshold like,
# Fraud Rate = 0, 'No Warning',
# Fraud Rate > 0 & <= 15, 'Warning',
# Fraud Rate > 15 & <= 40, 'Ban for Couple of Years',
# Fraud Rate > 40, 'Ban Completely', this is mentioned in the last feature Customer Classification (target)
#
# This is a solution which I expect to come these ban policies should be provided by the Ecommerce/logistics companies.

# %% [markdown]
# # Loading Data

# %%
# Import all Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Data
data = pd.read_excel('Dummy Data updated.xlsx')
data
# Out:
#     Seller ID  Items Sold out count  Items Returned count  Sold Frequency  \
# 0      100007                    15                     5             NaN
# 1      100008                     5                     2             NaN
# 2      100009                    10                     3             NaN
# 3      100010                    45                     8             NaN
# 4      100020                    30                     6             NaN
# ..        ...                   ...                   ...             ...
# 94     100847                    61                     5             NaN
# 95     100848                    68                     3             NaN
# 96     100849                    69                     6             NaN
# 97     100850                    62                     3             NaN
# 98     100851                    47                     5             NaN
#
#     Customer ID  Items ID  Transaction ID           Items Type  Return Date  \
# 0         56943      1591             NaN             Clothing          NaN
# 1         56943      1628             NaN   Shoes and Footwear          NaN
# 2         11226      1628             NaN   Shoes and Footwear          NaN
# 3         11226      1484             NaN  Bags Wallet Luggage          NaN
# 4          4760      1577             NaN   Electronic Gadgets          NaN
# ..          ...       ...             ...                  ...          ...
# 94         7988      1415             NaN       Sports Fitness          NaN
# 95         7988      1760             NaN      Home Appliances          NaN
# 96        57098      1077             NaN  Healthcare Products          NaN
# 97        57098      1415             NaN       Sports Fitness          NaN
# 98        57098      1415             NaN       Sports Fitness          NaN
#
#    Return Reason Pre Verification Return Request Post Verification  \
# 0     Wrong Item        Completed       Accepted        Fraudulent
# 1     Wrong Item        Completed       Accepted        Fraudulent
# 2   Damage Piece        Completed       Accepted           Genuine
# 3     Wrong Item          Pending   Not Accepted    Fail to return
# 4    Not Working        Completed       Accepted           Genuine
# ..           ...              ...            ...               ...
# 94    Wrong Item          Pending   Not Accepted    Fail to return
# 95   Not Working        Completed       Accepted        Fraudulent
# 96    Wrong Item        Completed       Accepted           Genuine
# 97    Wrong Item        Completed       Accepted           Genuine
# 98    Wrong Item          Pending   Not Accepted    Fail to return
#
#    Customer Complaints
# 0          Bad Service
# 1          Bad Service
# 2         Good Service
# 3        Not Satisfied
# 4         Good Service
# ..                 ...
# 94       Not Satisfied
# 95       Not Satisfied
# 96        Good Service
# 97        Good Service
# 98       Not Satisfied
#
# [99 rows x 14 columns]

# %% [markdown]
# # Feature Engineering

# %%
# Drop Unnecessary Features
data = data.drop(['Sold Frequency', 'Transaction ID', 'Return Date'],axis=1)
data.head()
# Out:
#    Seller ID  Items Sold out count  Items Returned count  Customer ID  \
# 0     100007                    15                     5        56943
# 1     100008                     5                     2        56943
# 2     100009                    10                     3        11226
# 3     100010                    45                     8        11226
# 4     100020                    30                     6         4760
#
#    Items ID           Items Type Return Reason Pre Verification  \
# 0      1591             Clothing    Wrong Item        Completed
# 1      1628   Shoes and Footwear    Wrong Item        Completed
# 2      1628   Shoes and Footwear  Damage Piece        Completed
# 3      1484  Bags Wallet Luggage    Wrong Item          Pending
# 4      1577   Electronic Gadgets   Not Working        Completed
#
#   Return Request Post Verification Customer Complaints
# 0       Accepted        Fraudulent         Bad Service
# 1       Accepted        Fraudulent         Bad Service
# 2       Accepted           Genuine        Good Service
# 3   Not Accepted    Fail to return       Not Satisfied
# 4       Accepted           Genuine        Good Service

# %%
data.columns
# Out:
# Index(['Seller ID', 'Items Sold out count', 'Items Returned count',
#        'Customer ID', 'Items ID', 'Items Type', 'Return Reason',
#        'Pre Verification', 'Return Request', 'Post Verification',
#        'Customer Complaints'],
#       dtype='object')

# %%
data.shape
# Out:
# (99, 11)

# %%
# Calculate Return Rate
data['Return Rate'] = (data['Items Returned count'] / data['Items Sold out count']) * 100

# Calculate Fraud Rate (adjust based on your criteria)
#data['Fraud Rate'] = (data['number_of_fraudulent_returns'] / data['total_number_of_returns']) * 100

# %%
data
# Out:
#     Seller ID  Items Sold out count  Items Returned count  Customer ID  \
# 0      100007                    15                     5        56943
# 1      100008                     5                     2        56943
# 2      100009                    10                     3        11226
# 3      100010                    45                     8        11226
# 4      100020                    30                     6         4760
# ..        ...                   ...                   ...          ...
# 94     100847                    61                     5         7988
# 95     100848                    68                     3         7988
# 96     100849                    69                     6        57098
# 97     100850                    62                     3        57098
# 98     100851                    47                     5        57098
#
#     Items ID           Items Type Return Reason Pre Verification  \
# 0       1591             Clothing    Wrong Item        Completed
# 1       1628   Shoes and Footwear    Wrong Item        Completed
# 2       1628   Shoes and Footwear  Damage Piece        Completed
# 3       1484  Bags Wallet Luggage    Wrong Item          Pending
# 4       1577   Electronic Gadgets   Not Working        Completed
# ..       ...                  ...           ...              ...
# 94      1415       Sports Fitness    Wrong Item          Pending
# 95      1760      Home Appliances   Not Working        Completed
# 96      1077  Healthcare Products    Wrong Item        Completed
# 97      1415       Sports Fitness    Wrong Item        Completed
# 98      1415       Sports Fitness    Wrong Item          Pending
#
#    Return Request Post Verification Customer Complaints  Return Rate
# 0        Accepted        Fraudulent         Bad Service    33.333333
# 1        Accepted        Fraudulent         Bad Service    40.000000
# 2        Accepted           Genuine        Good Service    30.000000
# 3    Not Accepted    Fail to return       Not Satisfied    17.777778
# 4        Accepted           Genuine        Good Service    20.000000
# ..            ...               ...                 ...          ...
# 94   Not Accepted    Fail to return       Not Satisfied     8.196721
# 95       Accepted        Fraudulent       Not Satisfied     4.411765
# 96       Accepted           Genuine        Good Service     8.695652
# 97       Accepted           Genuine        Good Service     4.838710
# 98   Not Accepted    Fail to return       Not Satisfied    10.638298
#
# [99 rows x 12 columns]

# %%
df = data.copy()

# %%
# Count the number of fraudulent returns for each customer, considering the count of items returned
fraudulent_returns_count = df[df['Post Verification'] == 'Fraudulent'].groupby('Customer ID')['Items Returned count'].sum().reset_index()
fraudulent_returns_count.columns = ['Customer ID', 'total_fraudulent_items_returned']

# Sum of total number of returns for each customer
total_returns_count = df.groupby('Customer ID')['Items Returned count'].sum().reset_index()
total_returns_count.columns = ['Customer ID', 'total_number_of_all_returns']  

# Merge the fraudulent and total returns counts with the original DataFrame
df = pd.merge(df, fraudulent_returns_count, on='Customer ID', how='left')
df = pd.merge(df, total_returns_count, on='Customer ID', how='left')

# Fill NaN values with 0 (customers without fraudulent returns)
df['total_fraudulent_items_returned'] = df['total_fraudulent_items_returned'].fillna(0)

# Calculate Fraud Rate
df['Fraud Rate'] = (df['total_fraudulent_items_returned'] / df['total_number_of_all_returns']) * 100

# %%
df
# Out:
#     Seller ID  Items Sold out count  Items Returned count  Customer ID  \
# 0      100007                    15                     5        56943
# 1      100008                     5                     2        56943
# 2      100009                    10                     3        11226
# 3      100010                    45                     8        11226
# 4      100020                    30                     6         4760
# ..        ...                   ...                   ...          ...
# 94     100847                    61                     5         7988
# 95     100848                    68                     3         7988
# 96     100849                    69                     6        57098
# 97     100850                    62                     3        57098
# 98     100851                    47                     5        57098
#
#     Items ID           Items Type Return Reason Pre Verification  \
# 0       1591             Clothing    Wrong Item        Completed
# 1       1628   Shoes and Footwear    Wrong Item        Completed
# 2       1628   Shoes and Footwear  Damage Piece        Completed
# 3       1484  Bags Wallet Luggage    Wrong Item          Pending
# 4       1577   Electronic Gadgets   Not Working        Completed
# ..       ...                  ...           ...              ...
# 94      1415       Sports Fitness    Wrong Item          Pending
# 95      1760      Home Appliances   Not Working        Completed
# 96      1077  Healthcare Products    Wrong Item        Completed
# 97      1415       Sports Fitness    Wrong Item        Completed
# 98      1415       Sports Fitness    Wrong Item          Pending
#
#    Return Request Post Verification Customer Complaints  Return Rate  \
# 0        Accepted        Fraudulent         Bad Service    33.333333
# 1        Accepted        Fraudulent         Bad Service    40.000000
# 2        Accepted           Genuine        Good Service    30.000000
# 3    Not Accepted    Fail to return       Not Satisfied    17.777778
# 4        Accepted           Genuine        Good Service    20.000000
# ..            ...               ...                 ...          ...
# 94   Not Accepted    Fail to return       Not Satisfied     8.196721
# 95       Accepted        Fraudulent       Not Satisfied     4.411765
# 96       Accepted           Genuine        Good Service     8.695652
# 97       Accepted           Genuine        Good Service     4.838710
# 98   Not Accepted    Fail to return       Not Satisfied    10.638298
#
#     total_fraudulent_items_returned  total_number_of_all_returns  Fraud Rate
# 0                               7.0                           17   41.176471
# 1                               7.0                           17   41.176471
# 2                               0.0                           19    0.000000
# 3                               0.0                           19    0.000000
# 4                               0.0                           29    0.000000
# ..                              ...                          ...         ...
# 94                             14.0                           54   25.925926
# 95                             14.0                           54   25.925926
# 96                             21.0                           42   50.000000
# 97                             21.0                           42   50.000000
# 98                             21.0                           42   50.000000
#
# [99 rows x 15 columns]

# %%
# Setting Threshold for customer classification
df['customer_classification'] = np.where(df['Fraud Rate'] == 0, 'No Warning',
                                         np.where((df['Fraud Rate'] > 0) & (df['Fraud Rate'] <= 15), 'Warning',
                                                  np.where((df['Fraud Rate'] > 15) & (df['Fraud Rate'] <= 40), 'Ban for Couple of Years',
                                                           'Ban Completely')))

# %%
df
# Out:
#     Seller ID  Items Sold out count  Items Returned count  Customer ID  \
# 0      100007                    15                     5        56943
# 1      100008                     5                     2        56943
# 2      100009                    10                     3        11226
# 3      100010                    45                     8        11226
# 4      100020                    30                     6         4760
# ..        ...                   ...                   ...          ...
# 94     100847                    61                     5         7988
# 95     100848                    68                     3         7988
# 96     100849                    69                     6        57098
# 97     100850                    62                     3        57098
# 98     100851                    47                     5        57098
#
#     Items ID           Items Type Return Reason Pre Verification  \
# 0       1591             Clothing    Wrong Item        Completed
# 1       1628   Shoes and Footwear    Wrong Item        Completed
# 2       1628   Shoes and Footwear  Damage Piece        Completed
# 3       1484  Bags Wallet Luggage    Wrong Item          Pending
# 4       1577   Electronic Gadgets   Not Working        Completed
# ..       ...                  ...           ...              ...
# 94      1415       Sports Fitness    Wrong Item          Pending
# 95      1760      Home Appliances   Not Working        Completed
# 96      1077  Healthcare Products    Wrong Item        Completed
# 97      1415       Sports Fitness    Wrong Item        Completed
# 98      1415       Sports Fitness    Wrong Item          Pending
#
#    Return Request Post Verification Customer Complaints  Return Rate  \
# 0        Accepted        Fraudulent         Bad Service    33.333333
# 1        Accepted        Fraudulent         Bad Service    40.000000
# 2        Accepted           Genuine        Good Service    30.000000
# 3    Not Accepted    Fail to return       Not Satisfied    17.777778
# 4        Accepted           Genuine        Good Service    20.000000
# ..            ...               ...                 ...          ...
# 94   Not Accepted    Fail to return       Not Satisfied     8.196721
# 95       Accepted        Fraudulent       Not Satisfied     4.411765
# 96       Accepted           Genuine        Good Service     8.695652
# 97       Accepted           Genuine        Good Service     4.838710
# 98   Not Accepted    Fail to return       Not Satisfied    10.638298
#
#     total_fraudulent_items_returned  total_number_of_all_returns  Fraud Rate  \
# 0                               7.0                           17   41.176471
# 1                               7.0                           17   41.176471
# 2                               0.0                           19    0.000000
# 3                               0.0                           19    0.000000
# 4                               0.0                           29    0.000000
# ..                              ...                          ...         ...
# 94                             14.0                           54   25.925926
# 95                             14.0                           54   25.925926
# 96                             21.0                           42   50.000000
# 97                             21.0                           42   50.000000
# 98                             21.0                           42   50.000000
#
#     customer_classification
# 0            Ban Completely
# 1            Ban Completely
# 2                No Warning
# 3                No Warning
# 4                No Warning
# ..                      ...
# 94  Ban for Couple of Years
# 95  Ban for Couple of Years
# 96           Ban Completely
# 97           Ban Completely
# 98           Ban Completely
#
# [99 rows x 16 columns]

# %%
# Save the DataFrame to a CSV file 
#df.to_csv('C:/Users/SONY/Downloads/Python/dummy data review.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 0 to 98
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Seller ID                        99 non-null     int64
#  1   Items Sold out count             99 non-null     int64
#  2   Items Returned count             99 non-null     int64
#  3   Customer ID                      99 non-null     int64
#  4   Items ID                         99 non-null     int64
#  5   Items Type                       99 non-null     object
#  6   Return Reason                    99 non-null     object
#  7   Pre Verification                 99 non-null     object
#  8   Return Request                   99 non-null     object
#  9   Post Verification                99 non-null     object
#  10  Customer Complaints              99 non-null     object
#  11  Return Rate                      99 non-null     float64
#  12  total_fraudulent_items_returned  99 non-null     float64
#  13  total_number_of_all_returns      99 non-null     int64
#  14  Fraud Rate                       99 non-null     float64
#  15  customer_classification          99 non-null     object
# dtypes: float64(3), int64(6), object(7)
# memory usage: 13.1+ KB

# %%
# Check for Missing value
df.isna().sum()
# Out:
# Seller ID                          0
# Items Sold out count               0
# Items Returned count               0
# Customer ID                        0
# Items ID                           0
# Items Type                         0
# Return Reason                      0
# Pre Verification                   0
# Return Request                     0
# Post Verification                  0
# Customer Complaints                0
# Return Rate                        0
# total_fraudulent_items_returned    0
# total_number_of_all_returns        0
# Fraud Rate                         0
# customer_classification            0
# dtype: int64

# %% [markdown]
# # Label Encoding

# %%
# Label Encoding
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['Items Type']= label_encoder.fit_transform(df['Items Type'])
df['Items Type'].unique()

df['Return Reason']= label_encoder.fit_transform(df['Return Reason'])
df['Return Reason'].unique()

df['Pre Verification']= label_encoder.fit_transform(df['Pre Verification'])
df['Pre Verification'].unique()

df['Return Request']= label_encoder.fit_transform(df['Return Request'])
df['Return Request'].unique()

df['Post Verification']= label_encoder.fit_transform(df['Post Verification'])
df['Post Verification'].unique()

df['Customer Complaints']= label_encoder.fit_transform(df['Customer Complaints'])
df['Customer Complaints'].unique()
# Out:
# array([0, 1, 2])

# %%
df.head()
# Out:
#    Seller ID  Items Sold out count  Items Returned count  Customer ID  \
# 0     100007                    15                     5        56943
# 1     100008                     5                     2        56943
# 2     100009                    10                     3        11226
# 3     100010                    45                     8        11226
# 4     100020                    30                     6         4760
#
#    Items ID  Items Type  Return Reason  Pre Verification  Return Request  \
# 0      1591           2              2                 0               0
# 1      1628           8              2                 0               0
# 2      1628           8              0                 0               0
# 3      1484           0              2                 1               1
# 4      1577           3              1                 0               0
#
#    Post Verification  Customer Complaints  Return Rate  \
# 0                  1                    0    33.333333
# 1                  1                    0    40.000000
# 2                  2                    1    30.000000
# 3                  0                    2    17.777778
# 4                  2                    1    20.000000
#
#    total_fraudulent_items_returned  total_number_of_all_returns  Fraud Rate  \
# 0                              7.0                           17   41.176471
# 1                              7.0                           17   41.176471
# 2                              0.0                           19    0.000000
# 3                              0.0                           19    0.000000
# 4                              0.0                           29    0.000000
#
#   customer_classification
# 0          Ban Completely
# 1          Ban Completely
# 2              No Warning
# 3              No Warning
# 4              No Warning

# %% [markdown]
# # Model Building

# %%
# Extract X and Y
X = df.drop(['customer_classification'], axis=1)
Y = df['customer_classification']

# %%
# Splitting the dataset
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,random_state=42,test_size=0.2)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logit_model = LogisticRegression()
logit_model.fit(X_train,Y_train)
Y_pred = logit_model.predict(X_test)

from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
print('Accuracy is:', accuracy_score(Y_test, Y_pred))
print('Micro Precision: {:.2f}'.format(precision_score(Y_test, Y_pred, average='micro')))
print('Micro Recall: {:.2f}'.format(recall_score(Y_test, Y_pred, average='micro')))
print('Micro F1-score: {:.2f}'.format(f1_score(Y_test, Y_pred, average='micro')))
# Out:
# Accuracy is: 0.95
# Micro Precision: 0.95
# Micro Recall: 0.95
# Micro F1-score: 0.95
# C:\Users\SONY\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
confusion_matrix(Y_test, Y_pred)
# Out:
# array([[14,  1,  0],
#        [ 0,  4,  0],
#        [ 0,  0,  1]], dtype=int64)

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier 
acc_values = []
neighbors = np.arange(2,50)
for K in neighbors:
    classifier = KNeighborsClassifier(n_neighbors=K, metric='minkowski')
    classifier.fit(X_train, Y_train)
    Y_pred=classifier.predict(X_test)
    acc=accuracy_score(Y_test, Y_pred)
    acc_values.append(acc)

# %%
acc_values
# Out:
# [0.95,
#  0.9,
#  0.95,
#  0.95,
#  0.95,
#  0.95,
#  1.0,
#  0.95,
#  0.95,
#  0.85,
#  0.9,
#  0.9,
#  0.85,
#  0.85,
#  0.85,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8,
#  0.8]

# %%
plt.plot(neighbors, acc_values, 'o-')
plt.xlabel('k value')
plt.ylabel('accuracy')
plt.grid()

# %%
classifier = KNeighborsClassifier(n_neighbors=7, metric='minkowski')
classifier.fit(X_train, Y_train)
Y_pred=classifier.predict(X_test)

print('Accuracy is:', accuracy_score(Y_test, Y_pred))
print('Micro Precision: {:.2f}'.format(precision_score(Y_test, Y_pred, average='micro')))
print('Micro Recall: {:.2f}'.format(recall_score(Y_test, Y_pred, average='micro')))
print('Micro F1-score: {:.2f}'.format(f1_score(Y_test, Y_pred, average='micro')))
# Out:
# Accuracy is: 0.95
# Micro Precision: 0.95
# Micro Recall: 0.95
# Micro F1-score: 0.95

# %%
confusion_matrix(Y_test, Y_pred)
# Out:
# array([[14,  0,  1],
#        [ 0,  4,  0],
#        [ 0,  0,  1]], dtype=int64)

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
Bayes_Gauss = GaussianNB()
Bayes_Gauss.fit(X_train, Y_train)
Y_pred = Bayes_Gauss.predict(X_test)

from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
print('Accuracy is:', accuracy_score(Y_test, Y_pred))
print('Micro Precision: {:.2f}'.format(precision_score(Y_test, Y_pred, average='micro')))
print('Micro Recall: {:.2f}'.format(recall_score(Y_test, Y_pred, average='micro')))
print('Micro F1-score: {:.2f}'.format(f1_score(Y_test, Y_pred, average='micro')))
# Out:
# Accuracy is: 0.9
# Micro Precision: 0.90
# Micro Recall: 0.90
# Micro F1-score: 0.90

# %%
confusion_matrix(Y_test, Y_pred)
# Out:
# array([[13,  2,  0],
#        [ 0,  4,  0],
#        [ 0,  0,  1]], dtype=int64)

# %%
Y_test.value_counts()
# Out:
# Ban Completely             15
# Ban for Couple of Years     4
# No Warning                  1
# Name: customer_classification, dtype: int64
